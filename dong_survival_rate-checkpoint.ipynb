# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set() #https://seaborn.pydata.org/generated/seaborn.set.html

# %matplotlib inline 
# %config InlineBackend.figure_format = 'retina'

# %%
seoul_map = folium.Map(location=[37.565784, 126.938572], zoom_start=11)
seoul_map.choropleth(geo_data='seoul_dong.json')
seoul_map
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\folium\folium.py:426: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import json

json_data=open("seoul_dong.json").read()
file = json.loads(json_data)

# %%
for i,child in enumerate(file["features"]) :
    print(i,child["properties"]["EMD_KOR_NM"])
# Out:
# 0 대방동
# 1 내수동
# 2 흑석동
# 3 창동
# 4 청량리동
# 5 전농동
# 6 이문동
# 7 휘경동
# 8 상도동
# 9 독산동
# 10 시흥동
# 11 개봉동
# 12 구로동
# 13 중학동
# 14 신당동
# 15 미아동
# 16 궁정동
# 17 응암동
# 18 내자동
# 19 수표동
# 20 신내동
# 21 방화동
# 22 예지동
# 23 명륜2가
# 24 신교동
# 25 경운동
# 26 신림동
# 27 봉천동
# 28 소격동
# 29 공평동
# 30 청진동
# 31 본동
# 32 장안동
# 33 도렴동
# 34 동작동
# 35 사당동
# 36 쌍문동
# 37 방학동
# 38 통인동
# 39 도봉동
# 40 제기동
# 41 누상동
# 42 답십리동
# 43 용두동
# 44 창성동
# 45 회기동
# 46 항동
# 47 세종로
# 48 신문로2가
# 49 삼청동
# 50 노량진동
# 51 팔판동
# 52 구산동
# 53 와룡동
# 54 계동
# 55 적선동
# 56 효자동
# 57 종로1가
# 58 안국동
# 59 신설동
# 60 증산동
# 61 논현동
# 62 상도1동
# 63 신대방동
# 64 진관동
# 65 가산동
# 66 가리봉동
# 67 고척동
# 68 신도림동
# 69 오류동
# 70 묵동
# 71 옥인동
# 72 사직동
# 73 필동1가
# 74 수색동
# 75 청운동
# 76 녹번동
# 77 불광동
# 78 갈현동
# 79 당주동
# 80 역촌동
# 81 신사동
# 82 명륜3가
# 83 상봉동
# 84 번동
# 85 자곡동
# 86 관훈동
# 87 서린동
# 88 창신동
# 89 숭인동
# 90 방산동
# 91 남학동
# 92 충무로3가
# 93 장교동
# 94 돈의동
# 95 면목동
# 96 과해동
# 97 공항동
# 98 효제동
# 99 익선동
# 100 재동
# 101 주자동
# 102 마곡동
# 103 토정동
# 104 오곡동
# 105 공릉동
# 106 돈암동
# 107 관수동
# 108 묘동
# 109 장사동
# ...

# %%
dong_survive_df = pd.read_csv('survival.csv')

# %%
dong_survive_df.head()
# Out:
#    법정동  생존+실패   생존      생존비율
# 0  가락동   1119  557  0.497766
# 1  가산동   1043  785  0.752637
# 2  가양동    225  175  0.777778
# 3  가회동      9    9  1.000000
# 4  갈현동    733  519  0.708049

# %%
seoul_map = folium.Map(location=[37.565784, 126.938572], zoom_start=11)

seoul_json = 'seoul_dong.json'
seoul_map.choropleth(geo_data=seoul_json, 
                     
                     data=dong_survive_df, 
                     columns=['법정동', '생존비율'], 
                     key_on='properties.EMD_KOR_NM', 
                     
                     ##style-related parameter setting 
                     fill_color='Blues', 
                     fill_opacity=0.7, 
                     line_opacity=0.5)

seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
