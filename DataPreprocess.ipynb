# %%
import pandas as pd

# %%
main = pd.read_csv('main_sheet_pre_final.csv',encoding='utf-8')

# %%
#상주인구 시작
sj_popul= pd.read_csv('average/sangju_popul.csv',encoding='euc-kr')

# %%
temp = pd.merge(main, sj_popul, on=['법정동'], how='left')

# %%
#소득소비 시작
sdsb = pd.read_csv('average/sodeksobi.csv',encoding='euc-kr')

# %%
temp2 = pd.merge(temp, sdsb, on=['법정동'], how='left')

# %%
#유동인구 시작
yudong_popul = pd.read_csv('average/yudong_popul.csv',encoding='utf-8')

# %%
temp3 = pd.merge(temp2, yudong_popul, on=['법정동'], how='left')

# %%
temp3.to_csv('merged_main_without_cjmc.csv',index=False, encoding='ms949')

# %%
#추정매출 붙이기
cjmc = pd.read_csv('average/chujeongmarchul.csv')

# %%
cjmc
# Out:
#        기준_년월_코드  상권_코드 상권_코드_명  법정동 서비스_업종_코드_명  평균_영업_개월_수  1년이하_생존_율  \
# 0        201810   1422   중대로9길  가락동      호프간이주점   44.200000      90.00
# 1        201810   1422   중대로9길  가락동        커피음료   35.422222      80.00
# 2        201810   1422   중대로9길  가락동         제과점   61.950000     100.00
# 3        201810   1422   중대로9길  가락동         치킨집   67.666667      33.33
# 4        201810   1422   중대로9길  가락동      패스트푸드점   83.615385     100.00
# 5        201810   1422   중대로9길  가락동         분식집   54.846154      58.33
# 6        201810   1422   중대로9길  가락동         양식집   45.558824     100.00
# 7        201810   1422   중대로9길  가락동         일식집   72.030303     100.00
# 8        201810   1422   중대로9길  가락동         중국집   69.769231      33.33
# 9        201810   1422   중대로9길  가락동       한식음식점   40.658228      65.15
# 10       201810   1121  오금로46길  가락동      호프간이주점   55.722222     100.00
# 11       201810   1121  오금로46길  가락동        커피음료   38.030303      80.00
# ...

# %%
cjmc = cjmc.groupby(['법정동','서비스_업종_코드_명']).sum()

# %%
cjmc.to_csv('cjmc.csv')

# %%
cjmc2 = pd.read_csv('cjmc.csv')

# %%
cjmc2
# Out:
#       법정동 서비스_업종_코드_명  기준_년월_코드  상권_코드   평균_영업_개월_수  1년이하_생존_율  1~2년_생존_율  \
# 0     가락동         분식집   1210857   7326   350.340033     391.66     250.00
# 1     가락동         양식집   1210857   7326   238.198346     400.00     400.00
# 2     가락동         일식집   1210857   7326   420.778971     400.00     133.32
# 3     가락동         제과점   1210857   7326   354.616667     400.00     400.00
# 4     가락동         중국집   1210857   7326   398.816239     133.32     133.32
# 5     가락동         치킨집   1210857   7326   335.483333     285.90     189.74
# 6     가락동        커피음료   1210857   7326   209.204549     453.34     420.00
# 7     가락동      패스트푸드점   1210857   7326   471.843379     520.00     480.00
# 8     가락동       한식음식점   1210857   7326   255.342815     389.56     275.40
# 9     가락동      호프간이주점   1210857   7326   285.633732     549.24     297.70
# 10    가산동         분식집   4036190  10068  1075.676118    1399.54    1158.40
# 11    가산동         양식집   4036190  10068   807.603574    1066.68     783.32
# ...

# %%
tlist = [
    ['분식집',['김밥(도시락)','분식']],
    ['양식집',['경양식','패밀리레스트랑']],
    ['일식집',['일식']],
    ['제과점',['제과점영업']],
    ['중국집',['중국식']],
    ['치킨집',['통닭(치킨)','호프/통닭']],
    ['커피음료',['까페','다방','전통찻집','커피숍']],
    ['패스트푸드점',['패스트푸드']],
    ['한식음식점',['냉면집','식육(숯불구이)','탕류(보신용)','한식']],
    ['호프간이주점',['감성주점','라이브카페','룸살롱','정종/대포집/소주방']]
]

# %%
tlist
# Out:
# [['분식집', ['김밥(도시락)', '분식']],
#  ['양식집', ['경양식', '패밀리레스트랑']],
#  ['일식집', ['일식']],
#  ['제과점', ['제과점영업']],
#  ['중국집', ['중국식']],
#  ['치킨집', ['통닭(치킨)', '호프/통닭']],
#  ['커피음료', ['까페', '다방', '전통찻집', '커피숍']],
#  ['패스트푸드점', ['패스트푸드']],
#  ['한식음식점', ['냉면집', '식육(숯불구이)', '탕류(보신용)', '한식']],
#  ['호프간이주점', ['감성주점', '라이브카페', '룸살롱', '정종/대포집/소주방']]]

# %%
def type_uni(a):
    for i in range(10):
        if a in tlist[i][1]:
            return tlist[i][0]
    return

# %%
temp3['type'] = temp3['업태명'].apply(type_uni)

# %%
cjmc2['type'] = cjmc2['서비스_업종_코드_명'].astype(str)

# %%
temp4 = pd.merge(temp3, cjmc2, on=['법정동', 'type'], how='left')

# %%
cjmc2
# Out:
#       법정동 서비스_업종_코드_명  기준_년월_코드  상권_코드   평균_영업_개월_수  1년이하_생존_율  1~2년_생존_율  \
# 0     가락동         분식집   1210857   7326   350.340033     391.66     250.00
# 1     가락동         양식집   1210857   7326   238.198346     400.00     400.00
# 2     가락동         일식집   1210857   7326   420.778971     400.00     133.32
# 3     가락동         제과점   1210857   7326   354.616667     400.00     400.00
# 4     가락동         중국집   1210857   7326   398.816239     133.32     133.32
# 5     가락동         치킨집   1210857   7326   335.483333     285.90     189.74
# 6     가락동        커피음료   1210857   7326   209.204549     453.34     420.00
# 7     가락동      패스트푸드점   1210857   7326   471.843379     520.00     480.00
# 8     가락동       한식음식점   1210857   7326   255.342815     389.56     275.40
# 9     가락동      호프간이주점   1210857   7326   285.633732     549.24     297.70
# 10    가산동         분식집   4036190  10068  1075.676118    1399.54    1158.40
# 11    가산동         양식집   4036190  10068   807.603574    1066.68     783.32
# ...

# %%
temp4
# Out:
#           시군구코드    년도  업소일련번호     허가신고일                업소명    법정동  \
# 0       3080000  2010       1  20100104          강영화동태내장전골    미아동
# 1       3100000  2010       1  20100104             명품갈매기살    상계동
# 2       3100000  2000    6639  20000115           태릉 닭 한마리    공릉동
# 3       3070000  1995    1835  19950315            소울키친 카페  안암동5가
# 4       3070000  2005       1  20050104          무아국수 족발보쌈  안암동5가
# 5       3130000  2004     242  20040503                  안    도화동
# 6       3130000  2010       1  20100104                  옥   노고산동
# 7       3130000  2010       2  20100104             모로미홍대점    서교동
# 8       3130000  2010       2  20100104        감성호프 탭탭 홍대점    서교동
# 9       3160000  2010       1  20100104               놀부지짐    고척동
# 10      3140000  2010       1  20100104              종로빈대떡    신정동
# 11      3140000  2010       2  20100104           성암축산정육식당    신월동
# 12      3220000  2003    1052  20031112               양지식당    삼성동
# ...

# %%
temp4.dropna(axis=0)
temp4
# Out:
#           시군구코드    년도  업소일련번호     허가신고일                업소명    법정동  \
# 0       3080000  2010       1  20100104          강영화동태내장전골    미아동
# 1       3100000  2010       1  20100104             명품갈매기살    상계동
# 2       3100000  2000    6639  20000115           태릉 닭 한마리    공릉동
# 3       3070000  1995    1835  19950315            소울키친 카페  안암동5가
# 4       3070000  2005       1  20050104          무아국수 족발보쌈  안암동5가
# 5       3130000  2004     242  20040503                  안    도화동
# 6       3130000  2010       1  20100104                  옥   노고산동
# 7       3130000  2010       2  20100104             모로미홍대점    서교동
# 8       3130000  2010       2  20100104        감성호프 탭탭 홍대점    서교동
# 9       3160000  2010       1  20100104               놀부지짐    고척동
# 10      3140000  2010       1  20100104              종로빈대떡    신정동
# 11      3140000  2010       2  20100104           성암축산정육식당    신월동
# 12      3220000  2003    1052  20031112               양지식당    삼성동
# ...

# %%
temp4.to_csv('test3.csv',encoding='ms949',index=False)

# %%
temp4 =  pd.merge(temp3, cjmc, on=['법정동'], how='left')

# %%
temp4.to_csv('merged_main.csv',encoding='ms949')
